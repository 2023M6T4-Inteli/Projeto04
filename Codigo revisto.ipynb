# %% [markdown]
# # Modelo de análise de sentimentos - AdTrack

# %% [markdown]
# Nesse notebook será contido o pipeline completo para gerar o modelo naive bayes com bag of words. Todo o desenvolvimento feito nas últimas 9 semanas está contido neste notebook, o objetivo é gerar o modelo .pickle a partir de uma base de dados previamente fornecida pelos parceiros de projeto.
#
# O motivo da escolha do modelo naive bayes foi que o mesmo obteve os melhores resultados com o pré processamento feito anteriormente, para mais detalhes dos outros modelos, análises gráficas do dataset e diferentes tratamentos do dataset acesse o readMe para mais detalhes.

# %% [markdown]
# ## Importando bibliotecas

# %% [markdown]
# Aqui são importadas as bibliotecas necessárias para realizar todo o processo contido no notebook.
# Caso não consiga executar alguma é só executar o comando :
# ```
# pip install {nome da biblioteca}
# ```

# %%
# !pip install emoji
# !pip show emoji
import pandas as pd
import numpy as np
import nltk
nltk.download('punkt')
from sklearn.feature_extraction.text import CountVectorizer
import ast
import emoji
from nltk.tokenize import word_tokenize
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, recall_score, ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt
import time
import pickle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (2.5.1)
# Name: emoji
# Version: 2.5.1
# Summary: Emoji for Python
# Home-page: https://github.com/carpedm20/emoji/
# Author: Taehoon Kim, Kevin Wurster
# Author-email: carpedm20@gmail.com
# License: New BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ## Pré processamento

# %% [markdown]
# Para executar o notebook é necessário o arquivo. csv , o mesmo já foi feito o pré processamento antes, visto que nós classificamos novamente os sentimentos de forma manual e para isso foram removidas todas as postagens que não eram de autoria do parceiro @btgpactual. Porém o processamento se aplica igualmente a uma base que não tenha sido tratada.

# %% [markdown]
# Para baixar o arquivo basta acessar o seguinte [link](https://drive.google.com/file/d/1Q3ZAA4q-ztKNKePnD2BcQyWWBjSRn5qJ/view?usp=sharing) o mesmo só é disponível para alunos e professores da turma por questões de segurança.
#
# Após efetuar o download só basta copiar o arquivo para a pasta “src” e começar a rodar todo o pipeline.

# %%
# Abrindo o csv
df = pd.read_csv('sentimento_revisado.csv')
df
# Out:
#                          autor  \
# 0                   lmviapiana
# 1                 vanilson_dos
# 2                  ricktolledo
# 3        paularodrigues.invest
# 4                rafael_miller
# ...                        ...
# 5662  perspectiveinvestimentos
# 5663              marlenenelso
# 5664            eduardocolares
# 5665             jayipacderota
# 5666                 bfmarilia
#
#                                                   texto sentimento  \
# 0                                  Minuto touro de ouro   POSITIVE
# 1                                      @ricktolledo Sim    NEUTRAL
# 2     Queria saber se a Btg banking é a própria btg ...   POSITIVE
# 3                                                  👏👏👏👏    NEUTRAL
# 4     Vamos ajudar o Brasil na principal categoria d...   POSITIVE
# ...                                                 ...        ...
# 5662                               Excelente explicação   POSITIVE
# 5663  Porque  o brg tá  diminuído  o limite  do cart...   NEGATIVE
# 5664               Atendam o telefone pelo amor de Deus   POSITIVE
# 5665  Estou muito grato por todo o esforço que você ...   POSITIVE
# 5666  @btgpactual pq o morning call não está mais ap...   NEGATIVE
#
#      tipoInteracao  anomalia  probabilidadeAnomalia  \
# 0       comentário         0                     38
# 1         resposta         0                     17
# 2       comentário         0                     20
# 3       comentário         0                     15
# 4       comentário         0                     41
# ...            ...       ...                    ...
# 5662    comentário         0                     15
# 5663    comentário         1                     53
# 5664    comentário         0                     28
# 5665    comentário         1                     52
# 5666    comentário         0                     28
#
#                                                linkPost  processado  \
# 0     https://www.instagram.com/p/CapXhB5Lvas/#17977...           0
# 1     https://www.instagram.com/p/CapXhB5Lvas/#17842...           0
# 2     https://www.instagram.com/p/CapXhB5Lvas/#17935...           0
# 3     https://www.instagram.com/p/CaptWrtOT8U/#17943...           0
# 4     https://www.instagram.com/p/CapoqJ3Ne7a/#17972...           0
# ...                                                 ...         ...
# 5662  https://www.instagram.com/p/ClgWR-Ov2H1/#18001...           0
# 5663  https://www.instagram.com/p/ClgWR-Ov2H1/#17878...           0
# 5664  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5665  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5666  https://www.instagram.com/p/CllkSBOuKlJ/#17975...           0
#
#       contemHyperlink                                    texto_e_palavra  \
# 0                   0                               Minuto touro de ouro
# 1                   0                                   @ricktolledo Sim
# 2                   0  Queria saber se a Btg banking é a própria btg ...
# 3                   0                       palmas palmas palmas palmas
# 4                   0  Vamos ajudar o Brasil na principal categoria d...
# ...               ...                                                ...
# 5662                0                               Excelente explicação
# 5663                0  Porque  o brg tá  diminuído  o limite  do cart...
# 5664                0               Atendam o telefone pelo amor de Deus
# 5665                0  Estou muito grato por todo o esforço que você ...
# 5666                0  @btgpactual pq o morning call não está mais ap...
#
#                                        texto_tokenizado  sentimento_revisto  \
# 0                           ['minuto', 'touro', 'ouro']                   1
# 1                                               ['sim']                   0
# 2             ['queria', 'saber', 'banking', 'própria']                   1
# 3              ['palmas', 'palmas', 'palmas', 'palmas']                   1
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...                   1
# ...                                                 ...                 ...
# 5662                        ['excelente', 'explicação']                  -1
# 5663  ['porque', 'brg', 'tá', 'diminuído', 'limite',...                  -1
# 5664            ['atendam', 'telefone', 'amor', 'deus']                  -1
# 5665  ['grato', 'todo', 'esforço', 'rendeu', 'invest...                  -1
# 5666  ['morning', 'call', 'aparecendo', 'spotify', '...                  -1
#
#                                       texto_tokenizado2
# 0                           ['minuto', 'touro', 'ouro']
# 1                                               ['sim']
# 2                        ['queria', 'saber', 'banking']
# 3              ['palmas', 'palmas', 'palmas', 'palmas']
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...
# ...                                                 ...
# 5662                        ['excelente', 'explicação']
# 5663  ['tá', 'diminuído', 'limite', 'do', 'cartão', ...
# 5664            ['atendam', 'telefone', 'amor', 'deus']
# 5665  ['muito', 'grato', 'todo', 'esforço', 'você', ...
# 5666  ['morning', 'call', 'não', 'mais', 'aparecendo...
#
# [5667 rows x 13 columns]

# %% [markdown]
# Como citado anteriormente, as colunas que já sofreram o processamento serão removidas para demonstrar todo o funcionamento do código.

# %%
df_inicial = df.drop(['texto_tokenizado', 'texto_e_palavra'], axis=1)
df
# Out:
#                          autor  \
# 0                   lmviapiana
# 1                 vanilson_dos
# 2                  ricktolledo
# 3        paularodrigues.invest
# 4                rafael_miller
# ...                        ...
# 5662  perspectiveinvestimentos
# 5663              marlenenelso
# 5664            eduardocolares
# 5665             jayipacderota
# 5666                 bfmarilia
#
#                                                   texto sentimento  \
# 0                                  Minuto touro de ouro   POSITIVE
# 1                                      @ricktolledo Sim    NEUTRAL
# 2     Queria saber se a Btg banking é a própria btg ...   POSITIVE
# 3                                                  👏👏👏👏    NEUTRAL
# 4     Vamos ajudar o Brasil na principal categoria d...   POSITIVE
# ...                                                 ...        ...
# 5662                               Excelente explicação   POSITIVE
# 5663  Porque  o brg tá  diminuído  o limite  do cart...   NEGATIVE
# 5664               Atendam o telefone pelo amor de Deus   POSITIVE
# 5665  Estou muito grato por todo o esforço que você ...   POSITIVE
# 5666  @btgpactual pq o morning call não está mais ap...   NEGATIVE
#
#      tipoInteracao  anomalia  probabilidadeAnomalia  \
# 0       comentário         0                     38
# 1         resposta         0                     17
# 2       comentário         0                     20
# 3       comentário         0                     15
# 4       comentário         0                     41
# ...            ...       ...                    ...
# 5662    comentário         0                     15
# 5663    comentário         1                     53
# 5664    comentário         0                     28
# 5665    comentário         1                     52
# 5666    comentário         0                     28
#
#                                                linkPost  processado  \
# 0     https://www.instagram.com/p/CapXhB5Lvas/#17977...           0
# 1     https://www.instagram.com/p/CapXhB5Lvas/#17842...           0
# 2     https://www.instagram.com/p/CapXhB5Lvas/#17935...           0
# 3     https://www.instagram.com/p/CaptWrtOT8U/#17943...           0
# 4     https://www.instagram.com/p/CapoqJ3Ne7a/#17972...           0
# ...                                                 ...         ...
# 5662  https://www.instagram.com/p/ClgWR-Ov2H1/#18001...           0
# 5663  https://www.instagram.com/p/ClgWR-Ov2H1/#17878...           0
# 5664  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5665  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5666  https://www.instagram.com/p/CllkSBOuKlJ/#17975...           0
#
#       contemHyperlink                                    texto_e_palavra  \
# 0                   0                               Minuto touro de ouro
# 1                   0                                   @ricktolledo Sim
# 2                   0  Queria saber se a Btg banking é a própria btg ...
# 3                   0                       palmas palmas palmas palmas
# 4                   0  Vamos ajudar o Brasil na principal categoria d...
# ...               ...                                                ...
# 5662                0                               Excelente explicação
# 5663                0  Porque  o brg tá  diminuído  o limite  do cart...
# 5664                0               Atendam o telefone pelo amor de Deus
# 5665                0  Estou muito grato por todo o esforço que você ...
# 5666                0  @btgpactual pq o morning call não está mais ap...
#
#                                        texto_tokenizado  sentimento_revisto  \
# 0                           ['minuto', 'touro', 'ouro']                   1
# 1                                               ['sim']                   0
# 2             ['queria', 'saber', 'banking', 'própria']                   1
# 3              ['palmas', 'palmas', 'palmas', 'palmas']                   1
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...                   1
# ...                                                 ...                 ...
# 5662                        ['excelente', 'explicação']                  -1
# 5663  ['porque', 'brg', 'tá', 'diminuído', 'limite',...                  -1
# 5664            ['atendam', 'telefone', 'amor', 'deus']                  -1
# 5665  ['grato', 'todo', 'esforço', 'rendeu', 'invest...                  -1
# 5666  ['morning', 'call', 'aparecendo', 'spotify', '...                  -1
#
#                                       texto_tokenizado2
# 0                           ['minuto', 'touro', 'ouro']
# 1                                               ['sim']
# 2                        ['queria', 'saber', 'banking']
# 3              ['palmas', 'palmas', 'palmas', 'palmas']
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...
# ...                                                 ...
# 5662                        ['excelente', 'explicação']
# 5663  ['tá', 'diminuído', 'limite', 'do', 'cartão', ...
# 5664            ['atendam', 'telefone', 'amor', 'deus']
# 5665  ['muito', 'grato', 'todo', 'esforço', 'você', ...
# 5666  ['morning', 'call', 'não', 'mais', 'aparecendo...
#
# [5667 rows x 13 columns]

# %% [markdown]
# ## Limpeza dos dados

# %% [markdown]
# A limpeza inicial remove as aspas dos nomes das colunas, todas as interações realizadas pelo autor 'btgpactual', comentários nulos (coluna 'texto') e qualquer interações que não sejam do tipo 'comentário' e 'resposta'

# %%
# Esta função remove os dados que não serão utilizados para a análise
def clean_data(df):
    # Remove as aspas dos nomes das colunas
    df = df.rename(columns=lambda x: x.replace('\"', ''))
    # Remove comentários feito pelo btg
    dfWithoutAutor = df[df["autor"] != "btgpactual"]
    # Remove comentários nulos
    dfWithoutNull = dfWithoutAutor[dfWithoutAutor["autor"].notnull()]
    # Deixando apenas as interações do tipo comentário e resposta
    dfFinal = dfWithoutNull.loc[(dfWithoutNull['tipoInteracao'] == 'comentário') | (dfWithoutNull['tipoInteracao'] == 'resposta')]
    return dfFinal

# %% [markdown]
# **Caso de teste**

# %% [markdown]
# Para garantir o correto funcionamento das funções a utilização de casos de teste é primordial. Então, antes da aplicação das funções é feito o caso de teste para realmente testar o funcionamento e se o output das funções é o esperado.

# %% [markdown]
# Nesta etapa é esperado que a função remova todos comentários de autoria do @btgpactual, remoção de dados nulos e remoção de todas interações diferentes de 'comentário' e 'resposta'.

# %%
# Criando um data frame de teste para validar o pré processamento
data_test = {'id': [1, 2, 3, 4, 5],
             'dataPublicada': ['03/01/2022', '03/04/2022', '03/07/2022', '03/10/2022', '31/12/2022'],
             'autor': ['btgpactual', 'robert87', 'grace46', 'william25', 'john23'],
             'texto': ["Obrigado, 🚀🚀💙", "Muito bom 👏👏👏👏",
                       "💙Bom dia, preciso urgente do meu informe de rendimentos do BTLG11 , para declaração do meu IR. Já enviei vários e-mails e até o momento sem resposta. Telefone ninguém atende. Como faço? 🐸", "Pessoal, sempre muito bom mas se eu puder solicitar uma coisa seria legendas 😅", "Sempre é aproveitoso parar o q tá fazendo para ouvi-lo"],
             'sentimento': ['NEUTRAL', 'NEUTRAL', 'NEGATIVE', 'POSITIVE', 'POSITIVE'],
             'tipoInteracao': ["comentário", "comentário", "comentário", "marcação", "comentário"],
             'anomalia': [1, 0, 0, 1, 1],
             'probabilidadeAnomalia': [100, 20, 30, 100, 100],
             'linkPost': ['https://www.instagram.com/p/CapXhB5Lvas/#17935401550894179', 'https://www.instagram.com/p/CaqBiRpsYLm/', 'https://www.instagram.com/p/CaqBiRpsYLm/', 'https://www.instagram.com/p/CapXhB5Lvas/#17926096268158628', 'https://www.instagram.com/p/CaR1j2TuPpD/#17914683365221503'],
             'processado': [0,0,0,1,1],
             'contemHyperlink': [0,0,0,1,1]}

df_testing = pd.DataFrame(data_test)
df_testing
# Out:
#    id dataPublicada       autor  \
# 0   1    03/01/2022  btgpactual
# 1   2    03/04/2022    robert87
# 2   3    03/07/2022     grace46
# 3   4    03/10/2022   william25
# 4   5    31/12/2022      john23
#
#                                                texto sentimento tipoInteracao  \
# 0                                      Obrigado, 🚀🚀💙    NEUTRAL    comentário
# 1                                     Muito bom 👏👏👏👏    NEUTRAL    comentário
# 2  💙Bom dia, preciso urgente do meu informe de re...   NEGATIVE    comentário
# 3  Pessoal, sempre muito bom mas se eu puder soli...   POSITIVE      marcação
# 4  Sempre é aproveitoso parar o q tá fazendo para...   POSITIVE    comentário
#
#    anomalia  probabilidadeAnomalia  \
# 0         1                    100
# 1         0                     20
# 2         0                     30
# 3         1                    100
# 4         1                    100
#
#                                             linkPost  processado  \
# 0  https://www.instagram.com/p/CapXhB5Lvas/#17935...           0
# 1           https://www.instagram.com/p/CaqBiRpsYLm/           0
# 2           https://www.instagram.com/p/CaqBiRpsYLm/           0
# 3  https://www.instagram.com/p/CapXhB5Lvas/#17926...           1
# 4  https://www.instagram.com/p/CaR1j2TuPpD/#17914...           1
#
#    contemHyperlink
# 0                0
# 1                0
# 2                0
# 3                1
# 4                1

# %%
# Testando a função
clean_data_test = df_testing
cleaning_test = clean_data(clean_data_test)
cleaning_test
# Out:
#    id dataPublicada     autor  \
# 1   2    03/04/2022  robert87
# 2   3    03/07/2022   grace46
# 4   5    31/12/2022    john23
#
#                                                texto sentimento tipoInteracao  \
# 1                                     Muito bom 👏👏👏👏    NEUTRAL    comentário
# 2  💙Bom dia, preciso urgente do meu informe de re...   NEGATIVE    comentário
# 4  Sempre é aproveitoso parar o q tá fazendo para...   POSITIVE    comentário
#
#    anomalia  probabilidadeAnomalia  \
# 1         0                     20
# 2         0                     30
# 4         1                    100
#
#                                             linkPost  processado  \
# 1           https://www.instagram.com/p/CaqBiRpsYLm/           0
# 2           https://www.instagram.com/p/CaqBiRpsYLm/           0
# 4  https://www.instagram.com/p/CaR1j2TuPpD/#17914...           1
#
#    contemHyperlink
# 1                0
# 2                0
# 4                1

# %% [markdown]
# Como esperado a função funcionou corretamente, então é possível prosseguir para as próximas etapas.

# %% [markdown]
# **Aplicando a função**

# %%
# Aplicando a função no data set real que será utilizado para treinar o modelo
cleaning_output = clean_data(df_inicial)
cleaning_output
# Out:
#                          autor  \
# 0                   lmviapiana
# 1                 vanilson_dos
# 2                  ricktolledo
# 3        paularodrigues.invest
# 4                rafael_miller
# ...                        ...
# 5662  perspectiveinvestimentos
# 5663              marlenenelso
# 5664            eduardocolares
# 5665             jayipacderota
# 5666                 bfmarilia
#
#                                                   texto sentimento  \
# 0                                  Minuto touro de ouro   POSITIVE
# 1                                      @ricktolledo Sim    NEUTRAL
# 2     Queria saber se a Btg banking é a própria btg ...   POSITIVE
# 3                                                  👏👏👏👏    NEUTRAL
# 4     Vamos ajudar o Brasil na principal categoria d...   POSITIVE
# ...                                                 ...        ...
# 5662                               Excelente explicação   POSITIVE
# 5663  Porque  o brg tá  diminuído  o limite  do cart...   NEGATIVE
# 5664               Atendam o telefone pelo amor de Deus   POSITIVE
# 5665  Estou muito grato por todo o esforço que você ...   POSITIVE
# 5666  @btgpactual pq o morning call não está mais ap...   NEGATIVE
#
#      tipoInteracao  anomalia  probabilidadeAnomalia  \
# 0       comentário         0                     38
# 1         resposta         0                     17
# 2       comentário         0                     20
# 3       comentário         0                     15
# 4       comentário         0                     41
# ...            ...       ...                    ...
# 5662    comentário         0                     15
# 5663    comentário         1                     53
# 5664    comentário         0                     28
# 5665    comentário         1                     52
# 5666    comentário         0                     28
#
#                                                linkPost  processado  \
# 0     https://www.instagram.com/p/CapXhB5Lvas/#17977...           0
# 1     https://www.instagram.com/p/CapXhB5Lvas/#17842...           0
# 2     https://www.instagram.com/p/CapXhB5Lvas/#17935...           0
# 3     https://www.instagram.com/p/CaptWrtOT8U/#17943...           0
# 4     https://www.instagram.com/p/CapoqJ3Ne7a/#17972...           0
# ...                                                 ...         ...
# 5662  https://www.instagram.com/p/ClgWR-Ov2H1/#18001...           0
# 5663  https://www.instagram.com/p/ClgWR-Ov2H1/#17878...           0
# 5664  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5665  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5666  https://www.instagram.com/p/CllkSBOuKlJ/#17975...           0
#
#       contemHyperlink  sentimento_revisto  \
# 0                   0                   1
# 1                   0                   0
# 2                   0                   1
# 3                   0                   1
# 4                   0                   1
# ...               ...                 ...
# 5662                0                  -1
# 5663                0                  -1
# 5664                0                  -1
# 5665                0                  -1
# 5666                0                  -1
#
#                                       texto_tokenizado2
# 0                           ['minuto', 'touro', 'ouro']
# 1                                               ['sim']
# 2                        ['queria', 'saber', 'banking']
# 3              ['palmas', 'palmas', 'palmas', 'palmas']
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...
# ...                                                 ...
# 5662                        ['excelente', 'explicação']
# 5663  ['tá', 'diminuído', 'limite', 'do', 'cartão', ...
# 5664            ['atendam', 'telefone', 'amor', 'deus']
# 5665  ['muito', 'grato', 'todo', 'esforço', 'você', ...
# 5666  ['morning', 'call', 'não', 'mais', 'aparecendo...
#
# [5667 rows x 11 columns]

# %% [markdown]
# # Pré processamento

# %% [markdown]
# Por se tratarem de comentários de redes sociais, muitos comentários possuem emojis e, dessa maneira, foi decidido realizar o seu tratamento para incluí-los no modelo. Assim, criou-se um dicionário de emojis em português, que são traduzidos e devolvidos em uma nova coluna do dataframe: 'texto_e_emoji'

# %%
# Dicionário com todos os emojis

emoji_dict = {
    '😀': 'feliz ',
    '😂': 'risos ',
    '😔': 'triste ',
    '👏': 'palmas ',
    '🥰': 'amável ',
    '💙': 'coração azul ',
    '🙏🏼': 'orando ',
    '✨': 'brilhando ',
    '🤮': 'nojo ',
    '🚀': 'foguete ',
    '👿': 'diabo ',
    '🤢': 'nojo ',
    '🔥': 'fogo ',
    '😡': 'fúria ',
    '😠': 'raiva ',
    '🤣': 'rindo ',
    '😃': 'feliz ',
    '😎': 'curtindo ',
    '😊': 'feliz ',
    '🤩': 'maravilhado ',
    '😋': 'delicioso ',
    '😆': 'risada ',
    '😌': 'calmo ',
    '🤔': 'pensativo ',
    '😷': 'máscara ',
    '🤣': 'muitoRiso ',
    '🥺': 'carinhoso ',
    '👍': 'positivo ',
    '🤯': 'menteExplodida ',
    '😅': 'alívio ',
    '🥰': 'carinhaComCoração ',
    '😓': 'suor ',
    '😑': 'tédio',
    '🤫': 'silêncio',
    '🤝': 'apertoDeMãos',
    '😊': 'sorriso',
    '😍': 'apaixonado',
    '😭': 'choro ',
    '🤗': 'abraço ',
    '🎉': 'festa ',
    '😎': 'descolado ',
    '😱': 'surpresa ',
    '😴': 'sono ',
    '🙌': 'celebração ',
    '🤔': 'pensativo ',
    '😘': 'beijo ',
    '🥳': 'festeiro ',
    '🙄': 'revirarOsOlhos ',
    '😌': 'alívio ',
    '🤫': 'segredo ',
    '😇': 'inocente ',
    '😂': 'muitoEngraçado ',
    '🤔': 'pensando ',
    '😴': 'sono ',
    '🤪': 'loucura ',
    '😢': 'decepcionadoAliviado ',
    '😬': 'nervoso ',
    '😌': 'alívio',
    '😔': 'triste ',
    '😞': 'desapontado ',
    '😢': 'choro ',
    '😭': 'chorando ',
    '😡': 'raiva ',
    '🤯': 'mente explodida ',
    '😳': 'surpreso ',
    '😱': 'gritando ',
    '😨': 'assustado ',
    '😴': 'sono ',
    '🥱': 'bocejando ',
    '🤢': 'enjoado ',
    '🤮': 'vomitando ',
    '🤧': 'espirro ',
    '🤒': 'doente ',
    '🤕': 'machucado ',
    '🤑': 'dinheiro ',
}

# %%
# Função que converte os emojis em palavras
def emoji_to_word(text):
    for emoji_code, emoji_word in emoji_dict.items():
        text = text.replace(emoji_code, emoji_word)
    return text

# %% [markdown]
# **Caso de Teste**

# %% [markdown]
# Nesta etapa é esperado que a função substitua todos os emojis por texto de acordo com o dicionário acima e seja criada uma nova coluna.

# %%
# Testando a função
emoji_test = cleaning_test
emoji_test['texto_e_emoji'] = emoji_test['texto'].apply(emoji_to_word)
emoji_test
# Out:
#    id dataPublicada     autor  \
# 1   2    03/04/2022  robert87
# 2   3    03/07/2022   grace46
# 4   5    31/12/2022    john23
#
#                                                texto sentimento tipoInteracao  \
# 1                                     Muito bom 👏👏👏👏    NEUTRAL    comentário
# 2  💙Bom dia, preciso urgente do meu informe de re...   NEGATIVE    comentário
# 4  Sempre é aproveitoso parar o q tá fazendo para...   POSITIVE    comentário
#
#    anomalia  probabilidadeAnomalia  \
# 1         0                     20
# 2         0                     30
# 4         1                    100
#
#                                             linkPost  processado  \
# 1           https://www.instagram.com/p/CaqBiRpsYLm/           0
# 2           https://www.instagram.com/p/CaqBiRpsYLm/           0
# 4  https://www.instagram.com/p/CaR1j2TuPpD/#17914...           1
#
#    contemHyperlink                                      texto_e_emoji
# 1                0             Muito bom palmas palmas palmas palmas
# 2                0  coração azul Bom dia, preciso urgente do meu i...
# 4                1  Sempre é aproveitoso parar o q tá fazendo para...

# %% [markdown]
# Como esperado a função funcionou corretamente, então é possível prosseguir para as próximas etapas.

# %% [markdown]
# **Aplicando a função**

# %%
# Aplicando a função e criando a colouna 'texto_e_emoji' como resultado
processing_output = cleaning_output
processing_output['texto_e_emoji'] = processing_output['texto'].apply(emoji_to_word)
processing_output
# Out:
#                          autor  \
# 0                   lmviapiana
# 1                 vanilson_dos
# 2                  ricktolledo
# 3        paularodrigues.invest
# 4                rafael_miller
# ...                        ...
# 5662  perspectiveinvestimentos
# 5663              marlenenelso
# 5664            eduardocolares
# 5665             jayipacderota
# 5666                 bfmarilia
#
#                                                   texto sentimento  \
# 0                                  Minuto touro de ouro   POSITIVE
# 1                                      @ricktolledo Sim    NEUTRAL
# 2     Queria saber se a Btg banking é a própria btg ...   POSITIVE
# 3                                                  👏👏👏👏    NEUTRAL
# 4     Vamos ajudar o Brasil na principal categoria d...   POSITIVE
# ...                                                 ...        ...
# 5662                               Excelente explicação   POSITIVE
# 5663  Porque  o brg tá  diminuído  o limite  do cart...   NEGATIVE
# 5664               Atendam o telefone pelo amor de Deus   POSITIVE
# 5665  Estou muito grato por todo o esforço que você ...   POSITIVE
# 5666  @btgpactual pq o morning call não está mais ap...   NEGATIVE
#
#      tipoInteracao  anomalia  probabilidadeAnomalia  \
# 0       comentário         0                     38
# 1         resposta         0                     17
# 2       comentário         0                     20
# 3       comentário         0                     15
# 4       comentário         0                     41
# ...            ...       ...                    ...
# 5662    comentário         0                     15
# 5663    comentário         1                     53
# 5664    comentário         0                     28
# 5665    comentário         1                     52
# 5666    comentário         0                     28
#
#                                                linkPost  processado  \
# 0     https://www.instagram.com/p/CapXhB5Lvas/#17977...           0
# 1     https://www.instagram.com/p/CapXhB5Lvas/#17842...           0
# 2     https://www.instagram.com/p/CapXhB5Lvas/#17935...           0
# 3     https://www.instagram.com/p/CaptWrtOT8U/#17943...           0
# 4     https://www.instagram.com/p/CapoqJ3Ne7a/#17972...           0
# ...                                                 ...         ...
# 5662  https://www.instagram.com/p/ClgWR-Ov2H1/#18001...           0
# 5663  https://www.instagram.com/p/ClgWR-Ov2H1/#17878...           0
# 5664  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5665  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5666  https://www.instagram.com/p/CllkSBOuKlJ/#17975...           0
#
#       contemHyperlink  sentimento_revisto  \
# 0                   0                   1
# 1                   0                   0
# 2                   0                   1
# 3                   0                   1
# 4                   0                   1
# ...               ...                 ...
# 5662                0                  -1
# 5663                0                  -1
# 5664                0                  -1
# 5665                0                  -1
# 5666                0                  -1
#
#                                       texto_tokenizado2  \
# 0                           ['minuto', 'touro', 'ouro']
# 1                                               ['sim']
# 2                        ['queria', 'saber', 'banking']
# 3              ['palmas', 'palmas', 'palmas', 'palmas']
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...
# ...                                                 ...
# 5662                        ['excelente', 'explicação']
# 5663  ['tá', 'diminuído', 'limite', 'do', 'cartão', ...
# 5664            ['atendam', 'telefone', 'amor', 'deus']
# 5665  ['muito', 'grato', 'todo', 'esforço', 'você', ...
# 5666  ['morning', 'call', 'não', 'mais', 'aparecendo...
#
#                                           texto_e_emoji
# 0                                  Minuto touro de ouro
# 1                                      @ricktolledo Sim
# 2     Queria saber se a Btg banking é a própria btg ...
# 3                          palmas palmas palmas palmas
# 4     Vamos ajudar o Brasil na principal categoria d...
# ...                                                 ...
# 5662                               Excelente explicação
# 5663  Porque  o brg tá  diminuído  o limite  do cart...
# 5664               Atendam o telefone pelo amor de Deus
# 5665  Estou muito grato por todo o esforço que você ...
# 5666  @btgpactual pq o morning call não está mais ap...
#
# [5667 rows x 12 columns]

# %% [markdown]
# ## Tokenização e remoção de stop words

# %% [markdown]
# A partir do tratamento de emojis, agora é aplicada a tokenização das frases, em que são separadas por palavras e, depois, removidas as palavras que não apresentam significado semântico relevante ao modelo, chamadas stop words, como por exemplo: 'de', 'para', 'ou' e todas as demais consideradas stop words pelo stakeholder. Assim, não foram utilizadas bibliotecas de stop words visando trazer uma solução mais customizada tendo em mente a indústria do parceiro.

# %%
def processText(text):
    # Converter palavras da frase para minúsculas
    text = text.lower()
    # Tokenizar o texto em palavras
    tokens = word_tokenize(text)
    # Remover stopwords das palavras tokenizadas
    stop_words = ['@', 'banco', 'btg', 'brg', 'pactual', 'btgpactual','pq', 'q', 'pra', 'vcs', 'vc', 'i', 'p', 'kkk', 'y', 'of', 'n', 'a', 'à', 'as', 'o', 'os', 'e', 'aos', 'do', 'das', 'dos', 'das', 'de', 'deles', 'dela', 'deles', 'delas', 'para', 'que', 'em', 'algo', 'algum', 'alguma', 'alguns', 'algumas', 'aqui', 'aquele', 'aquela', 'aqueles', 'aquelas', 'aqui', 'aquilo', 'cá', 'com', 'como', 'cada', 'coisa', 'daquele', 'daquela', 'daquilo', 'daqueles', 'daquelas', 'desse', 'deste', 'dessa', 'desses', 'destes', 'destas', 'ele', 'eles', 'ela', 'elas', 'eu', 'nos', 'nós', 'vocês', 'voces', 'enquanto', 'era',  'está', 'estamos', 'estão', 'estar', 'estará', 'estive', 'estivemos', 'estiver', 'estivera', 'estiveram', 'estivéramos', 'estiverem', 'estivermos', 'estivesse','estivessem', 'estivéssemos', 'estiveste', 'estivestes', 'estou',  'fará', 'farta', 'farto', 'fez', 'fim', 'foi', 'fomos', 'for', 'fora', 'foram', 'fôramos', 'forem', 'formos', 'fosse', 'fossem', 'fôssemos','foste', 'fostes', 'fui', 'fôssemos', 'há', 'houve', 'hoje', 'isso', 'isto', 'já', 'lá', 'lhe', 'lhes', 'lo', 'logo',  'mas', 'me', 'mesma', 'mesmas', 'mesmo', 'mesmos', 'meu', 'meus',  'minha', 'minhas', 'na', 'no', 'nas', 'nos', 'naquela', 'naquelas', 'naquele', 'naqueles', 'nem', 'nessa', 'nessas', 'nesse', 'nesses', 'nesta', 'nestas', 'neste', 'nestes', 'ninguém', 'nosso', 'nossa', 'nossos', 'nossas', 'num', 'numa', 'outra', 'outras', 'outro', 'outros', 'pela', 'pelo', 'perante', 'pois', 'ponto', 'pontos', 'por', 'porém', 'porque', 'porquê', 'própria', 'próprio', 'próprias', 'próprios', 'qual', 'quando', 'quanto', 'quantos', 'quantas', 'quê', 'quem', 'quer', 'quereis', 'querem', 'queremas', 'quis', 'quisemos', 'quiser', 'quisera', 'quiseram','quiséramos', 'quiserem', 'quisermos', 'quisésseis', 'quiséssemos', 'quiseste', 'quisestes', 'quiseste','quisestes', 'quizer', 'quizeram', 'quizerem', 'quizermos', 'quizesse', 'quizessem', 'quizéssemos', 'são', 'se', 'seja', 'sejam', 'sejamos', 'sem', 'sendo', 'ser', 'será', 'serão', 'será', 'seriam', 'seríamos','serias', 'seríeis', 'sete', 'seu', 'seus', 'sob', 'sobre', 'sois', 'só','somos', 'sou', 'sua', 'suas', 'tal', 'talvez', 'também', 'te', 'tem', 'têm', 'temos', 'tendes', 'tenha', 'tenham', 'tenhamos', 'tenho', 'tens', 'ter', 'terá', 'terão','terá', 'teriam', 'teríamos', 'terias', 'teríeis', 'teu', 'teus', 'teve', 'tivemos', 'tiver', 'tivera','tiveram', 'tivéramos', 'tiverem', 'tivermos', 'tivesse', 'tivessem', 'tivéssemos', 'tiveste', 'tivestes','tiveste', 'tivestes', 'um', 'uma', 'umas', 'uns','é' ]
    # Retorna a lista de comentários sem as palavras setadas para serem removidas
    tokens = [token for token in tokens if token not in stop_words if not token.startswith('@') and token.isalpha()]
    # Retorna o resultado da frase tokenizada, sem stopWords
    return tokens

# %% [markdown]
# **Caso de Teste**

# %% [markdown]
# Nesta etapa é esperado que a função deixe todos os textos da coluna 'texto_e_emoji' em minúsculo, tokenize o texto, remova todas stop words, retire todas as marcações que utilizam @ e remova todos tokens que não sejam letras do alfabeto.

# %%
# Aplicando a função no caso de teste e criando a coluna 'tokens_processados'
emoji_test['tokens_processados'] = emoji_test['texto_e_emoji'].apply(processText)
emoji_test.reset_index(drop=True, inplace=True)
emoji_test
# Out:
#    id dataPublicada     autor  \
# 0   2    03/04/2022  robert87
# 1   3    03/07/2022   grace46
# 2   5    31/12/2022    john23
#
#                                                texto sentimento tipoInteracao  \
# 0                                     Muito bom 👏👏👏👏    NEUTRAL    comentário
# 1  💙Bom dia, preciso urgente do meu informe de re...   NEGATIVE    comentário
# 2  Sempre é aproveitoso parar o q tá fazendo para...   POSITIVE    comentário
#
#    anomalia  probabilidadeAnomalia  \
# 0         0                     20
# 1         0                     30
# 2         1                    100
#
#                                             linkPost  processado  \
# 0           https://www.instagram.com/p/CaqBiRpsYLm/           0
# 1           https://www.instagram.com/p/CaqBiRpsYLm/           0
# 2  https://www.instagram.com/p/CaR1j2TuPpD/#17914...           1
#
#    contemHyperlink                                      texto_e_emoji  \
# 0                0             Muito bom palmas palmas palmas palmas
# 1                0  coração azul Bom dia, preciso urgente do meu i...
# 2                1  Sempre é aproveitoso parar o q tá fazendo para...
#
#                                   tokens_processados
# 0       [muito, bom, palmas, palmas, palmas, palmas]
# 1  [coração, azul, bom, dia, preciso, urgente, in...
# 2          [sempre, aproveitoso, parar, tá, fazendo]

# %% [markdown]
# Como esperado a função funcionou corretamente, então é possível prosseguir para as próximas etapas.

# %% [markdown]
# **Aplicando a função**

# %%
#Aplicar a função em uma única variável para aplicar nos modelos
processed_tokens = processing_output['texto_e_emoji'].apply(processText)
processed_tokens
# Out:
# 0                                   [minuto, touro, ouro]
# 1                                      [ricktolledo, sim]
# 2                    [queria, saber, banking, administra]
# 3                        [palmas, palmas, palmas, palmas]
# 4       [vamos, ajudar, brasil, principal, categoria, ...
#                               ...
# 5662                              [excelente, explicação]
# 5663    [tá, diminuído, limite, cartão, sempre, pagamo...
# 5664                      [atendam, telefone, amor, deus]
# 5665    [muito, grato, todo, esforço, você, rendeu, in...
# 5666    [morning, call, não, mais, aparecendo, spotify...
# Name: texto_e_emoji, Length: 5667, dtype: object

# %%
# Aplicando a função no dataset original para criar a coluna

processing_output['tokens_processados'] = processing_output['texto_e_emoji'].apply(processText)
processing_output.reset_index(drop=True, inplace=True)
processing_output
# Out:
#                          autor  \
# 0                   lmviapiana
# 1                 vanilson_dos
# 2                  ricktolledo
# 3        paularodrigues.invest
# 4                rafael_miller
# ...                        ...
# 5662  perspectiveinvestimentos
# 5663              marlenenelso
# 5664            eduardocolares
# 5665             jayipacderota
# 5666                 bfmarilia
#
#                                                   texto sentimento  \
# 0                                  Minuto touro de ouro   POSITIVE
# 1                                      @ricktolledo Sim    NEUTRAL
# 2     Queria saber se a Btg banking é a própria btg ...   POSITIVE
# 3                                                  👏👏👏👏    NEUTRAL
# 4     Vamos ajudar o Brasil na principal categoria d...   POSITIVE
# ...                                                 ...        ...
# 5662                               Excelente explicação   POSITIVE
# 5663  Porque  o brg tá  diminuído  o limite  do cart...   NEGATIVE
# 5664               Atendam o telefone pelo amor de Deus   POSITIVE
# 5665  Estou muito grato por todo o esforço que você ...   POSITIVE
# 5666  @btgpactual pq o morning call não está mais ap...   NEGATIVE
#
#      tipoInteracao  anomalia  probabilidadeAnomalia  \
# 0       comentário         0                     38
# 1         resposta         0                     17
# 2       comentário         0                     20
# 3       comentário         0                     15
# 4       comentário         0                     41
# ...            ...       ...                    ...
# 5662    comentário         0                     15
# 5663    comentário         1                     53
# 5664    comentário         0                     28
# 5665    comentário         1                     52
# 5666    comentário         0                     28
#
#                                                linkPost  processado  \
# 0     https://www.instagram.com/p/CapXhB5Lvas/#17977...           0
# 1     https://www.instagram.com/p/CapXhB5Lvas/#17842...           0
# 2     https://www.instagram.com/p/CapXhB5Lvas/#17935...           0
# 3     https://www.instagram.com/p/CaptWrtOT8U/#17943...           0
# 4     https://www.instagram.com/p/CapoqJ3Ne7a/#17972...           0
# ...                                                 ...         ...
# 5662  https://www.instagram.com/p/ClgWR-Ov2H1/#18001...           0
# 5663  https://www.instagram.com/p/ClgWR-Ov2H1/#17878...           0
# 5664  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5665  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5666  https://www.instagram.com/p/CllkSBOuKlJ/#17975...           0
#
#       contemHyperlink  sentimento_revisto  \
# 0                   0                   1
# 1                   0                   0
# 2                   0                   1
# 3                   0                   1
# 4                   0                   1
# ...               ...                 ...
# 5662                0                  -1
# 5663                0                  -1
# 5664                0                  -1
# 5665                0                  -1
# 5666                0                  -1
#
#                                       texto_tokenizado2  \
# 0                           ['minuto', 'touro', 'ouro']
# 1                                               ['sim']
# 2                        ['queria', 'saber', 'banking']
# 3              ['palmas', 'palmas', 'palmas', 'palmas']
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...
# ...                                                 ...
# 5662                        ['excelente', 'explicação']
# 5663  ['tá', 'diminuído', 'limite', 'do', 'cartão', ...
# 5664            ['atendam', 'telefone', 'amor', 'deus']
# 5665  ['muito', 'grato', 'todo', 'esforço', 'você', ...
# 5666  ['morning', 'call', 'não', 'mais', 'aparecendo...
#
#                                           texto_e_emoji  \
# 0                                  Minuto touro de ouro
# 1                                      @ricktolledo Sim
# 2     Queria saber se a Btg banking é a própria btg ...
# 3                          palmas palmas palmas palmas
# 4     Vamos ajudar o Brasil na principal categoria d...
# ...                                                 ...
# 5662                               Excelente explicação
# 5663  Porque  o brg tá  diminuído  o limite  do cart...
# 5664               Atendam o telefone pelo amor de Deus
# 5665  Estou muito grato por todo o esforço que você ...
# 5666  @btgpactual pq o morning call não está mais ap...
#
#                                      tokens_processados
# 0                                 [minuto, touro, ouro]
# 1                                    [ricktolledo, sim]
# 2                  [queria, saber, banking, administra]
# 3                      [palmas, palmas, palmas, palmas]
# 4     [vamos, ajudar, brasil, principal, categoria, ...
# ...                                                 ...
# 5662                            [excelente, explicação]
# 5663  [tá, diminuído, limite, cartão, sempre, pagamo...
# 5664                    [atendam, telefone, amor, deus]
# 5665  [muito, grato, todo, esforço, você, rendeu, in...
# 5666  [morning, call, não, mais, aparecendo, spotify...
#
# [5667 rows x 13 columns]

# %% [markdown]
# ### Conclusão pré processamento

# %% [markdown]
# Com as etapas acima prontas o pré processamento está concluido. Assim, foi possível remover comentários que não fazem sentido para o treino do modelo, tratamento de emojis, remoção de stop words customizada e a tokenização dos comentários.

# %% [markdown]
# ## Aplicação do modelo Bag of Words

# %% [markdown]
# A função abaixo vetoriza todas as palavras contidas na coluna 'tokens_processados' e retorna um vocabulário a partir delas. Posteriormente esses vetores serão utilizados para a aplicação dos modelos.

# %%
#A função abaixo obtém o dicionário e os vetores para, posteriormente, ser aplicado nos modelos

def bag_of_words(frases):
    vectorizer = CountVectorizer()
    frases = [' '.join(tokens) for tokens in frases]
    bow_representation = vectorizer.fit_transform(frases)
    dictionary = vectorizer.vocabulary_

    return bow_representation, dictionary

# %%
bow_representation2, dictionary2 = bag_of_words(processed_tokens)
bow_representation2, dictionary2
# Out:
# (<5667x9427 sparse matrix of type '<class 'numpy.int64'>'
#  	with 49380 stored elements in Compressed Sparse Row format>,
#  {'minuto': 5882,
#   'touro': 8729,
#   'ouro': 6446,
#   'ricktolledo': 7878,
#   'sim': 8206,
#   'queria': 7421,
#   'saber': 7970,
#   'banking': 1043,
#   'administra': 202,
#   'palmas': 6516,
#   'vamos': 9021,
#   'ajudar': 330,
#   'brasil': 1268,
#   'principal': 7145,
#   'categoria': 1556,
#   'automobilismo': 937,
#   'mundo': 6025,
#   'ambev': 458,
#   'xpinvestimentos': 9338,
#   'havanoficial': 4500,
#   'bancodobrasil': 1018,
#   'clarobrasi': 1725,
#   'nubank': 6242,
#   'itau': 5064,
#   'santander': 8023,
#   'wegelectric': 9304,
#   'tanta': 8474,
#   'conta': 2149,
#   'digital': 2872,
#   'dando': 2458,
#   'baile': 993,
#   'bancos': 1023,
#   'raios': 7464,
#   'continuam': 2168,
#   'itaú': 5069,
#   'hora': 4559,
#   'dar': 2467,
#   'adeus': 185,
#   'escolha': 3435,
#   'bancointer': 1019,
#   'feliz': 3912,
#   'carinhacomcoração': 1513,
#   'itaufoi': 5066,
#   'ruim': 7948,
#   'desde': 2697,
#   'sempre': 8115,
#   'nunca': 6253,
#   'vai': 8988,
#   'mudar': 5997,
#   'instagram': 4891,
#   'deixa': 2545,
#   'publicar': 7324,
#   'imagens': 4644,
#   'post': 6976,
#   'então': 3365,
#   'não': 6261,
#   'conseguiram': 2085,
#   'colacar': 1796,
#   'dy': 3074,
#   'reorganizar': 7708,
#   'layout': 5284,
#   'postar': 6982,
#   'imagem': 4643,
#   'fica': 3944,
#   'dica': 2848,
#   'galera': 4229,
#   'cadê': 1404,
#   'dividendos': 2977,
#   'choro': 1687,
#   'apenas': 616,
#   'mostrar': 5951,
#   'apreço': 678,
#   'mulher': 6016,
#   'levou': 5346,
#   'zero': 9372,
#   'herói': 4526,
#   'muito': 6006,
#   'entre': 3348,
#   'equipe': 3401,
#   'vencedora': 9066,
#   'mostrarei': 5952,
#   'gratidão': 4412,
#   'trabalharei': 8742,
#   'você': 9233,
#   'coração': 2248,
#   'azul': 975,
#   'foguete': 4076,
#   'eita': 3145,
#   'existe': 3702,
#   'responder': 7771,
#   'direct': 2905,
#   'simples': 8211,
#   'pergunta': 6744,
#   'pode': 6881,
#   'melhorar': 5727,
#   'até': 912,
#   'fazendo': 3859,
#   'vistas': 9193,
#   'grossas': 4430,
#   'comigo': 1874,
#   'preciso': 7039,
#   'resposta': 7788,
#   'negócio': 6148,
#   'ficar': 3949,
#   'sério': 8444,
#   'mandei': 5596,
#   'privado': 7163,
#   'responde': 7768,
#   'jeito': 5104,
#   'vou': 9271,
#   'falar': 3794,
#   'tudo': 8868,
#   'alocar': 397,
#   'valor': 9002,
#   'nova': 6229,
#   'atualização': 907,
#   'recomendo': 7560,
#   'maior': 5564,
#   'investimentos': 4991,
#   'da': 2445,
#   'américa': 497,
#   'latina': 5279,
#   'maravilhado': 5636,
#   'disciplina': 2920,
#   'horário': 4566,
#   'especial': 3481,
#   'quarta': 7398,
#   'cade': 1399,
#   'informe': 4831,
#   'app': 659,
#   'gosto': 4385,
#   'demais': 2573,
#   'confiança': 2021,
#   'inovandopalmas': 4864,
#   'personalidade': 6770,
#   'incrível': 4748,
#   'grandes': 4407,
#   'qualidades': 7392,
#   'liderança': 5372,
#   'lelitunse': 5310,
#   'acreditei': 163,
#   'mãos': 6051,
#   'sucesso': 8377,
#   'seguiu': 8078,
#   'inicialmente': 4846,
#   'depositei': 2620,
#   'dias': 2846,
#   'recebi': 7520,
#   'credibilidade': 2328,
#   'esquecida': 3526,
#   'triste': 8836,
#   'poderiam': 6889,
#   'obrigada': 6280,
#   'feriado': 3921,
#   'cancelado': 1455,
#   'assim': 797,
#   'bovegas': 1251,
#   'fechada': 3877,
#   'povo': 7004,
#   'trabalhadormuitoengraçado': 8738,
#   'provavelmente': 7280,
#   'investe': 4979,
#   'fundo': 4199,
#   'imobiliário': 4656,
#   'gerido': 4320,
#   'criaram': 2355,
#   'página': 7355,
#   'investidores': 4986,
#   'recebendo': 7514,
#   'rendimentos': 7699,
#   'abri': 44,
#   'consigo': 2112,
#   'verificar': 9115,
#   'essa': 3537,
#   'situação': 8245,
#   'respondem': 7769,
#   'mds': 5698,
#   'informações': 4830,
#   'corretas': 2276,
#   'dá': 3075,
#   'cuidado': 2391,
#   'agora': 277,
#   'estagiário': 3557,
#   'sarou': 8036,
#   'ressaca': 7791,
#   'alívio': 432,
#   'muitoriso': 6014,
#   'fonte': 4085,
#   'andré': 526,
#   'esteves': 3584,
#   'dono': 3027,
#   'exame': 3658,
#   'preso': 7107,
#   'lava': 5280,
#   'jato': 5095,
#   'arapio': 715,
#   'dedos': 2524,
#   'dizem': 2990,
#   'experts': 3721,
#   'sabem': 7967,
#   'funcionamento': 4182,
#   'errada': 3409,
#   'acessar': 98,
#   'deveria': 2815,
#   'funcionar': 4184,
#   'carnaval': 1518,
#   'retirada': 7823,
#   'tão': 8882,
#   'grande': 4406,
#   'investir': 4995,
#   'realmente': 7503,
#   'mudou': 6003,
#   'vida': 9144,
#   'esta': 3544,
#   'semana': 8103,
#   'obrigado': 6281,
#   'bom': 1222,
#   'trabalho': 8746,
#   'opera': 6368,
#   'partir': 6594,
#   'errrrou': 3421,
#   'hahahahahhaha': 4487,
#   'operações': 6379,
#   'dia': 2837,
#   'apartir': 614,
#   'retifiquem': 7821,
#   'informação': 4829,
#   'feira': 3901,
#   'haverá': 4506,
#   'abre': 41,
#   'cecilioandrade': 1580,
#   'muitoengraçado': 6007,
#   'melhor': 5721,
#   'todos': 8674,
#   'digitais': 2871,
#   'uso': 8955,
#   'arrependo': 755,
#   'boto': 1248,
#   'dinheiro': 2899,
#   'muita': 6004,
#   'cobra': 1761,
#   'taxa': 8493,
#   'saques': 8035,
#   'ótimo': 9412,
#   'arlindocorreia': 731,
#   'link': 5419,
#   'bio': 1147,
#   'assessor': 791,
#   'pronto': 7246,
#   'auxiliar': 953,
#   'vão': 9282,
#   'aumentar': 922,
#   'corretagem': 2273,
#   'avisando': 967,
#   'caiocaito': 1414,
#   'concordo': 1986,
#   'sei': 8091,
#   'aplicativo': 635,
#   'investimento': 4990,
#   'home': 4543,
#   'broker': 1300,
#   'pro': 7168,
#   'lmarquine': 5442,
#   'enviei': 3381,
#   'solicitações': 8284,
#   'transferência': 8780,
#   'custódia': 2430,
#   'migrar': 5843,
#   'teixeiragilmarvasconcelos': 8512,
#   'alternativas': 413,
#   'tesouro': 8579,
#   'selic': 8100,
#   'cdbs': 1575,
#   'liquidez': 5423,
#   'diária': 2996,
#   'pagam': 6481,
#   'menos': 5758,
#   'cdi': 1577,
#   'encontra': 3260,
#   'esses': 3541,
#   'fiasco': 3942,
#   'nomes': 6204,
#   'excelentefoguete': 3664,
#   'alo': 395,
#   'bilionarios': 1143,
#   'brasileiros': 1273,
#   'lucianohangbr': 5486,
#   'pgmsilviosantos': 6815,
#   'fundacaolemann': 4192,
#   'boicote': 1198,
#   'ao': 579,
#   'comprometimento': 1943,
#   'abrir': 48,
#   'gratuitamente': 4417,
#   'palmeiras': 6517,
#   'fazer': 3860,
#   'liga': 5376,
#   'futebol': 4208,
#   'botafogo': 1243,
#   'forte': 4116,
#   'parece': 6564,
#   'excluiu': 3675,
#   'aí': 979,
#   'arrumar': 765,
#   'bilhão': 1141,
#   'kkkkkkkkk': 5217,
#   'john': 5135,
#   'textor': 8595,
#   'comprar': 1929,
#   'subir': 8370,
#   'sarrafo': 8037,
#   'srs': 8353,
#   'mandar': 5592,
#   'começou': 1872,
#   'falência': 3825,
#   'brasileiro': 1272,
#   'querer': 7420,
#   'flamengo': 4026,
#   'mania': 5604,
#   'inclua': 4724,
#   'favor': 3852,
#   'mim': 5862,
#   'fogo': 4074,
#   'boa': 1184,
#   'live': 5428,
#   'oi': 6332,
#   'bem': 1104,
#   'adequados': 181,
#   'objetivo': 6275,
#   'parabéns': 6535,
#   'altairprofetaprofeta': 404,
#   'estava': 3574,
#   'pensando': 6696,
#   'semelhança': 8110,
#   'dois': 3020,
#   'ataques': 833,
#   'vladimir': 9225,
#   'putin': 7348,
#   've': 9045,
#   'ucrânia': 8897,
#   'alemães': 361,
#   'viam': 9138,
#   'polônia': 6910,
#   'mais': 5568,
#   'confuso': 2045,
#   'ainda': 323,
#   'vez': 9130,
#   'pior': 6833,
#   'ricocomvc': 7880,
#   'investem': 4981,
#   'xp': 9337,
#   'largam': 5265,
#   'rico': 7879,
#   'lado': 5239,
#   'ir': 5020,
#   'elcietets': 3147,
#   'buscar': 1368,
#   'cdb': 1574,
#   'pague': 6496,
#   'alinhadas': 383,
#   'objetivos': 6276,
#   'sorriso': 8323,
#   'turma': 8873,
#   'fera': 3918,
#   'acompanhando': 128,
#   'vídeo': 9286,
#   'inspirador': 4884,
#   'bt': 1309,
#   'btgpactualarcusbuaiz': 1323,
#   'casa': 1544,
#   'economia': 3101,
#   'depois': 2618,
#   'capitão': 1489,
#   'cloroquina': 1746,
#   'campanha': 1438,
#   'politica': 6899,
#   'evento': 3643,
#   'fã': 4214,
#   'apaixonado': 590,
#   'rei': 7659,
#   'rachadinha': 7452,
#   'cartão': 1540,
#   'corporativo': 2255,
#   'alvarosfrasson': 426,
#   'aniversário': 536,
#   'ganha': 4236,
#   'ouvir': 6457,
#   'análises': 575,
#   'comentários': 1854,
#   'amigo': 478,
#   'nectoninvestimentos': 6113,
#   'juntos': 5180,
#   'celebração': 1588,
#   'juuuurrrraaaaa': 5195,
#   'mentecaptos': 5773,
#   'falam': 3790,
#   'óbvio': 9405,
#   'morrem': 5941,
#   'medo': 5707,
#   'esquerda': 3531,
#   'destrói': 2790,
#   'show': 8183,
#   'horror': 4561,
#   'senhor': 8121,
#   'bizarro': 1157,
#   'diferente': 2859,
#   'conferência': 2012,
#   'aconteceu': 141,
#   'bozonaro': 1255,
#   'destilando': 2781,
#   'mentiras': 5780,
#   'impropérios': 4694,
#   'vento': 9093,
#   'tb': 8497,
#   'acho': 118,
#   'ar': 713,
#   'embora': 3193,
#   'capaz': 1485,
#   'explicar': 3727,
#   'seleto': 8097,
#   'definido': 2535,
#   'passar': 6606,
#   'expressão': 3745,
#   'seriedade': 8153,
#   'falo': 3812,
#   'ido': 4610,
#   'nenhum': 6156,
#   'cia': 1694,
#   'basta': 1065,
#   'olhar': 6343,
#   'publicações': 7327,
#   'história': 4536,
#   'empresa': 3220,
#   'cerbasi': 1611,
#   'incluindo': 4727,
#   'esse': 3539,
#   'time': 8631,
#   'mirna': 5888,
#   'bona': 1226,
#   'enfim': 3277,
#   'pareceu': 6566,
#   'rasgação': 7476,
#   'ceda': 1581,
#   'sentimento': 8135,
#   'move': 5966,
#   'volta': 9237,
#   'cnpj': 1755,
#   'ponta': 6914,
#   'caso': 1551,
#   'estaria': 3565,
#   'deixando': 2549,
#   'investido': 4984,
#   'entendo': 3336,
#   'inglês': 4837,
#   'tu': 8864,
#   'escolhacelebração': 3436,
#   'btgapaixonado': 1313,
#   'inclusivo': 4730,
#   'concorrente': 1988,
#   'duas': 3059,
#   'letras': 5333,
#   'experiência': 3718,
#   'ótima': 9410,
#   'surpreendi': 8420,
#   'ja': 5078,
#   'melhoria': 5735,
#   'seguro': 8088,
#   'veicular': 9049,
#   'shop': 8179,
#   'loja': 5450,
#   'integrada': 4913,
#   'referência': 7631,
#   'enviar': 3378,
#   'cobrado': 1763,
#   'digo': 2877,
#   'chegou': 1670,
#   'colocando': 1812,
#   'bolsopalmas': 1221,
#   'thlimaoficial': 8612,
#   'taxas': 8496,
#   'cashback': 1550,
#   'sala': 8001,
#   'vip': 9171,
#   'aeroporto': 236,
#   'programa': 7215,
#   'controle': 2206,
#   'despesas': 2760,
#   'sinto': 8238,
#   'menor': 5756,
#   'saudade': 8042,
#   'cliente': 1738,
#   'pouco': 6997,
#   'tempo': 8524,
#   'reclamar': 7538,
#   'dispensam': 2933,
#   'top': 8698,
#   'jhonataagustinho': 5115,
#   'acesso': 102,
#   'ou': 6445,
#   'pagar': 6486,
#   'fatura': 3848,
#   'sistema': 8240,
#   'segurança': 8086,
#   'super': 8401,
#   'cheio': 1673,
#   'bugs': 1357,
#   'solução': 8302,
#   'urgência': 8938,
#   'vários': 9280,
#   'aguardo': 307,
#   'transtorno': 8796,
#   'motivo': 5959,
#   'senha': 8120,
#   'bloqueada': 1170,
#   'deram': 2627,
#   'esclarecimento': 3430,
#   'ajuda': 325,
#   'suporte': 8411,
#   'conseguindo': 2083,
#   'tentei': 8553,
#   'chat': 1648,
#   'sac': 7973,
#   'redefinir': 7591,
#   'facial': 3774,
#   'péssima': 7362,
#   'nenhuma': 6157,
#   'foto': 4124,
#   'funcionando': 4183,
#   'parede': 6570,
#   'branca': 1264,
#   'local': 5443,
#   'iluminado': 4641,
#   'sugestões': 8386,
#   'fiagro': 3940,
#   'ações': 978,
#   'alôooooo': 436,
#   'joaoadibemarques': 5119,
#   'crefisa': 2334,
#   'leosancheztv': 5324,
#   'clarobrasil': 1726,
#   'bora': 1234,
#   'pifitti': 6826,
#   'seria': 8151,
#   'pena': 6684,
#   'momento': 5921,
#   'alguém': 371,
#   'bancar': 1015,
#   'pietro': 6825,
#   'btgpactualempresas': 1332,
#   'alô': 434,
#   'ronaldo': 7924,
#   'petrobras': 6805,
#   'mrv': 5982,
#   'fertipar': 3930,
#   'amo': 483,
#   'mastercard': 5677,
#   'black': 1161,
#   'benefício': 1116,
#   'mercado': 5788,
#   'cc': 1573,
#   'remunerada': 7686,
#   'funciona': 4176,
#   'cadastro': 1397,
#   'finalizou': 3983,
#   'descobri': 2672,
#   'ia': 4592,
#   'aai': 1,
#   'lucrando': 5490,
#   'indicados': 4763,
#   'achei': 116,
#   'péssimo': 7363,
#   'sair': 7997,
#   'reidasutileza': 7660,
#   'bank': 1041,
#   'pontuação': 6920,
#   'átomos': 9389,
#   'tô': 8891,
#   'ligado': 5379,
#   'piada': 6816,
#   'valem': 8993,
#   'rafinha': 7462,
#   'bastos': 1068,
#   'mandou': 5598,
#   'abraço': 39,
#   'competente': 1905,
#   'recomendam': 7551,
#   'eua': 3629,
#   'vomitando': 9252,
#   'completo': 1913,
#   'verdade': 9100,
#   'tá': 8879,
#   'vandofogo': 9024,
#   'ate': 834,
#   'satisfeito': 8040,
#   'serviços': 8163,
#   'btgmais': 1316,
#   'finalmente': 3984,
#   'unificar': 8915,
#   'peço': 6809,
#   'primeiro': 7139,
#   'legal': 5294,
#   'prática': 7291,
#   'dizer': 2993,
#   'necessário': 6110,
#   'realizar': 7498,
#   'todas': 8670,
#   'bancárias': 1026,
#   'consultas': 2139,
#   'continuará': 2176,
#   'dora': 3031,
#   'maravilhosaapaixonado': 5638,
#   'pô': 7369,
#   'falta': 3818,
#   'faz': 3857,
#   'senti': 8132,
#   'kkkkk': 5213,
#   'sugestão': 8385,
#   'futuro': 4210,
#   'implementem': 4672,
#   'gustavopaulinno': 4463,
#   'responsivo': 7785,
#   'opção': 6398,
#   'crédito': 2381,
#   'celular': 1592,
#   'pareça': 6574,
#   'função': 4202,
#   'pactualapaixonado': 6474,
#   'aeeeee': 234,
#   'querendo': 7419,
#   'simplificar': 8215,
#   'apaixonadopalmas': 603,
#   'maravilha': 5635,
#   'faltando': 3820,
#   'derivados': 2629,
#   'continuaremos': 2174,
#   'corretora': 2279,
#   'bola': 1199,
#   'excelente': 3663,
#   'entendi': 3334,
#   'virou': 9182,
#   'apps': 662,
#   'seguem': 8067,
#   'separados': 8141,
#   'demaisss': 2575,
#   'flu': 4038,
#   'criar': 2354,
#   'entrar': 3345,
#   'joão': 5154,
#   'dória': 3089,
#   'ator': 867,
#   'ego': 3137,
#   'sr': 8350,
#   'acontece': 137,
#   'causa': 1560,
#   'dele': 2563,
#   'culpa': 2399,
#   'governo': 4396,
#   'federal': 3892,
#   'kkkk': 5212,
#   'piadista': 6817,
#   'esqueça': 3534,
#   'governa': 4392,
#   'motor': 5963,
#   'faltava': 3821,
#   'crescer': 2339,
#   'população': 6924,
#   'bolso': 1208,
#   'elegeu': 3151,
#   'cidadão': 1702,
#   'posso': 6965,
#   'deixar': 2550,
#   'parado': 6541,
#   'corrente': 2263,
#   'usar': 8947,
#   'poupança': 7000,
#   'aonde': 581,
#   'possa': 6957,
#   'guardado': 4439,
#   'rendendo': 7695,
#   'acessor': 103,
#   'comprou': 1946,
#   'magalu': 5552,
#   'preço': 7133,
#   'fodeu': 4073,
#   'gritando': 4429,
#   'suor': 8400,
#   'apaixonadoapaixonadoapaixonado': 592,
#   'dinhoycemanor': 2901,
#   'voto': 9268,
#   'turno': 8874,
#   'ficouu': 3960,
#   'nome': 6203,
#   'trader': 8749,
#   'difícil': 2867,
#   'pretendem': 7122,
#   'contas': 2156,
#   'inves': 4975,
#   'gostei': 4384,
#   'peso': 6784,
#   'teremos': 8564,
#   'ver': 9095,
#   'palestra': 6509,
#   'gravada': 4420,
#   'simplesmente': 8212,
#   'perfeito': 6738,
#   'detalhe': 2796,
#   'conhecimento': 2061,
#   'oque': 6401,
#   'toppppalmas': 8705,
#   'papo': 6529,
#   'após': 709,
#   'ano': 538,
#   'portabilidade': 6935,
#   'salário': 8015,
#   'aprovaram': 692,
#   'fiz': 4019,
#   'limite': 5400,
#   'sabe': 7965,
#   'informar': 4826,
#   'séria': 8441,
#   'ok': 6336,
#   'tirou': 8657,
#   'dúvida': 3090,
#   'cadastrar': 1395,
#   'faco': 3780,
#   'perguntou': 6750,
#   'fórmula': 4220,
#   'perfeita': 6736,
#   'brilhando': 1292,
#   'saque': 8031,
#   'aprecio': 665,
#   'prometo': 7239,
#   'compartilhar': 1897,
#   'apertodemãos': 618,
#   'quase': 7399,
#   'horas': 4560,
#   'respondi': 7775,
#   'mensagem': 5761,
#   'mandaram': 5593,
#   'falaram': 3795,
#   'conjunta': 2064,
#   'resto': 7806,
#   'patrocina': 6628,
#   'biahaddadmaia': 1133,
#   'disso': 2954,
#   'urgente': 8934,
#   'borges': 1237,
#   'carolinamendonca': 1524,
#   'fefarah': 3896,
#   'dentre': 2599,
#   'tantas': 8475,
#   'mulheres': 6017,
#   'incríveis': 4747,
#   'melsouzass': 5739,
#   'anygconrado': 573,
#   'silvaneidepalmeira': 8202,
#   'flah': 4025,
#   'gabriellaacruz': 4224,
#   'joaochristiem': 5121,
#   'uau': 8894,
#   'gostaria': 4382,
#   'elogiar': 3176,
#   'desenvolvedores': 2709,
#   'serviço': 8162,
#   'ficou': 3959,
#   'fantástico': 3835,
#   'levantei': 5337,
#   'atrás': 894,
#   'dispostos': 2949,
#   'atendimento': 850,
#   'promoção': 7242,
#   'incentivar': 4715,
#   'maravilhosa': 5637,
#   'admiro': 214,
#   'desbloqueia': 2662,
#   'renda': 7692,
#   'variável': 9038,
#   'resolveu': 7753,
#   'rápido': 7961,
#   'indignação': 4774,
#   'pagando': 6485,
#   'antes': 560,
#   'diminuíram': 2893,
#   'dezembro': 2835,
#   'fique': 4004,
#   'tranquila': 8766,
#   'definitiva': 2537,
#   'fazem': 3858,
#   'novamente': 6230,
#   'vem': 9058,
#   'real': 7490,
#   'desagradável': 2645,
#   'alegibinlibman': 357,
#   'danibilli': 2460,
#   'todo': 8673,
#   'bugado': 1353,
#   'trava': 8809,
#   'animação': 533,
#   'inicial': 4844,
#   'novo': 6237,
#   'péssimos': 7364,
#   'piores': 6835,
#   'cobrando': 1765,
#   'cancelei': 1463,
#   'dentro': 2600,
#   'prazo': 7019,
#   'forma': 4100,
#   'totalmente': 8725,
#   'injusta': 4858,
#   'lastimável': 5275,
#   'plataforma': 6860,
#   'ordem': 6407,
#   'ontem': 6363,
#   'profit': 7209,
#   'travou': 8817,
#   'status': 8355,
#   'modificação': 5914,
#   'pendente': 6686,
#   'cancelar': 1459,
#   'centenas': 1599,
#   'vezes': 9131,
#   'conseguia': 2079,
#   'vídeos': 9287,
#   'erro': 3416,
#   'mail': 5562,
#   'descontando': 2685,
#   'podem': 6882,
#   'contato': 2159,
#   'neologica': 6168,
#   'informaram': 4827,
#   'verificamos': 9113,
#   'questão': 7435,
#   'remete': 7682,
#   'pendência': 6690,
#   'junto': 5179,
#   'processa': 7179,
#   'executa': 3679,
#   'ordens': 6408,
#   'bolsa': 1207,
#   'normalmente': 6214,
#   'requisitada': 7732,
#   'precisa': 7027,
#   'aprovar': 691,
#   'aberta': 25,
#   'agendada': 266,
#   'final': 3978,
#   'executada': 3680,
#   'agendei': 267,
#   'executei': 3683,
#   'sai': 7990,
#   'prejuízo': 7065,
#   'mil': 5848,
#   'reais': 7488,
#   'passou': 6613,
#   'homem': 4545,
#   'resgatar': 7741,
#   'instituição': 4899,
#   'assessoria': 796,
#   'lamentável': 5256,
#   'olá': 6351,
#   'esclarecer': 3427,
#   'qualquer': 7394,
#   'processo': 7181,
#   'ativação': 862,
#   'token': 8676,
#   'reconhecimento': 7569,
#   'invesimentos': 4976,
#   'onde': 6359,
#   'etc': 3622,
#   'refazer': 7626,
#   'segue': 8066,
#   'desta': 2776,
#   'constantemente': 2120,
#   'maneira': 5599,
#   'feito': 3904,
#   'feita': 3902,
#   'autenticação': 932,
#   'biometria': 1150,
#   'permaneça': 6758,
#   'ativo': 864,
#   'ambos': 465,
#   'toda': 8669,
#   'projeto': 7227,
#   'enquadra': 3307,
#   'experienciadomar': 3714,
#   'política': 6906,
#   'horrível': 4564,
#   'relação': 7675,
#   'atrasa': 875,
#   'chance': 1641,
#   'diminuir': 2884,
#   'usa': 8943,
#   'frequência': 4152,
#   'novidade': 6235,
#   'meses': 5806,
#   'usando': 8946,
#   'faturas': 3851,
#   'específico': 3491,
#   'tiram': 8647,
#   'insatisfação': 4868,
#   'arrependimento': 754,
#   'mata': 5678,
#   'base': 1062,
#   'anos': 539,
#   'financeiro': 3991,
#   'fundamento': 4198,
#   'foco': 4070,
#   'claro': 1724,
#   'apareceu': 608,
#   'tentando': 8546,
#   'saldo': 8006,
#   'entrei': 3354,
#   'telefone': 8516,
#   'resolve': 7748,
#   'manter': 5623,
#   'puderem': 7333,
#   'alterar': 409,
#   'vizualizaçar': 9223,
#   'ativos': 865,
#   'porcentagem': 6927,
#   'sensacional': 8124,
#   'visualizar': 9197,
#   'rentabilidade': 7704,
#   'dificuldade': 2863,
#   'feio': 3900,
#   'seguir': 8077,
#   'design': 2731,
#   'particularmente': 6591,
#   'curtimos': 2420,
#   'opa': 6364,
#   'muitomorgulhosonde': 6008,
#   'horroroso': 4563,
#   'espalhado': 3479,
#   'achar': 114,
#   'mexer': 5823,
#   'escolher': 3441,
#   'versão': 9126,
#   'antiga': 562,
#   'podiam': 6895,
#   'continuar': 2171,
#   'antigo': 564,
#   'fácil': 4213,
#   'prático': 7292,
#   'além': 430,
#   'visualmente': 9199,
#   'agradável': 292,
#   'bonito': 1230,
#   'gráficos': 4435,
#   'visualização': 9198,
#   'aparece': 604,
#   'mínimo': 6065,
#   'máximo': 6048,
#   'permite': 6760,
#   'histórico': 4538,
#   'períodos': 6780,
#   'maiores': 5565,
#   'crismartinsreis': 2369,
#   'guerreiras': 4445,
#   'viva': 9209,
#   'luizzguic': 5507,
#   'paap': 6465,
#   'demora': 2587,
#   'solucionar': 8300,
#   'bastasse': 1067,
#   'travada': 8810,
#   'operação': 6378,
#   'decepcionada': 2503,
#   'gostava': 4383,
#   'desejar': 2701,
#   'resolução': 7746,
#   'problemas': 7174,
#   'adianta': 186,
#   'resolvem': 7749,
#   'retorno': 7840,
#   'complicado': 1918,
#   'espera': 3492,
#   'visual': 9196,
#   'novas': 6231,
#   'funcionalidades': 4179,
#   'interface': 4940,
#   'clean': 1732,
#   'funcionalpalmas': 4180,
#   'ligar': 5383,
#   'segunda': 8079,
#   'conversarmos': 2221,
#   'abs': 56,
#   'dúvidas': 3091,
#   'longefogo': 5454,
#   'completa': 1910,
#   'qualidade': 7391,
#   'arrepender': 750,
#   'felipe': 3910,
#   'dm': 3000,
#   'interesse': 4938,
#   'assessora': 792,
#   'trocar': 8841,
#   'certeza': 1617,
#   'eqiinvestimentos': 3395,
#   'indico': 4771,
#   'usei': 8952,
#   ...})

# %%
df_revised_feeling = processing_output

# %%
encoder = LabelEncoder()
numeric_sentiment = encoder.fit_transform(df_revised_feeling['sentimento'])

# Dividir os dados em treino e teste
X_treino, X_teste, y_treino, y_teste = train_test_split(bow_representation2, numeric_sentiment, test_size=0.2, random_state=42)

# Criar e treinar o modelo Naive Bayes
model = MultinomialNB()
start_time = time.time()
model.fit(X_treino, y_treino)

# Fazer a predição usando os dados de teste
prediction = model.predict(X_teste)

# Avaliar a acurácia do modelo
accuracy = (prediction == y_teste).mean()
print(f"Acurácia:, {accuracy:.2%}")

# Calcular o recall
recall = recall_score(y_teste, prediction, average='weighted')
print(f"Recall:, {recall:.2%}")
# Calcular a matriz de confusão
confusion_matrix = confusion_matrix(y_teste, prediction)

# Mapear os valores originais para os rótulos desejados
mapping = {0: 'Negativo', 1: 'Neutro', 2: 'Positivo'}
mapped_confusion_matrix = np.vectorize(mapping.get)(confusion_matrix)

# Criar a matriz de confusão no estilo desejado
cm = ConfusionMatrixDisplay(confusion_matrix, display_labels=['Negativo', 'Neutro', 'Positivo'])
cm.plot()
cm.ax_.set(
    title='Matriz de Confusão',
    xlabel='Classe Prevista',
    ylabel='Classe Real'
)
plt.show()


end_time = time.time()
execution_time = end_time - start_time
print(f"Tempo de execução: {execution_time:.5f} segundos")


# Após treinar o modelo
with open('modelo_naive_bayes.pkl', 'wb') as file:
    pickle.dump(model, file)
# Out:
# Acurácia:, 73.37%
# Recall:, 73.37%
# Tempo de execução: 0.34909 segundos
